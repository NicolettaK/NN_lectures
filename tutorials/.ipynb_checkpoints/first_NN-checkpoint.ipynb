# %% [markdown]
# # Build a simple fully connected NN from scratch
# This tutorial has been modified from the presented in the "CS231n: Convolutional Neural Networks for Visual Recognition" course of Stanford University.
#
# http://cs231n.stanford.edu

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Create datasets

# %%
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
Xtot = np.zeros((N*K,D)) # data matrix (each row = single example)
y_true_tot = np.zeros(N*K, dtype='uint8') # class labels
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.3 # theta
    Xtot[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y_true_tot[ix] = j

# %%
plt.scatter(Xtot[:, 0], Xtot[:, 1], c=y_true_tot[:], s=40, cmap=plt.cm.viridis)
plt.savefig('tutorial1_spiral.pdf')

# %% [markdown]
# # Train a Linear Classifier

# %% [markdown]
# first we build a linear classifier: this can be thought as a NN with two layers (input and output) where NO activation is applied
#
#
# <img src="liner_classifier_img.png" alt="drawing" width="300"/>

# %%
# initialize parameters randomly
X = Xtot
y_true = y_true_tot
W = np.random.randn(D,K)
b = np.zeros((1,K))

# learning rate
step_size = 1e-0

# gradient descent loop
num_examples = X.shape[0]

for i in range(10000):
  
  # evaluate output
    y = np.dot(X, W) + b 
  
  # compute the class probabilities
    exp_y = np.exp(y)
    probs = exp_y / np.sum(exp_y, axis=1, keepdims=True) # [N x K]
  
  # compute the loss: average cross-entropy loss
    loss = -np.log(probs[range(num_examples),y_true])
    cost = np.sum(loss)/num_examples
    if i % 1000 == 0:
        print("iteration %d: cost %f" % (i, cost))
  
  # derivative w.r.t. y
    dy = probs
    dy[range(num_examples),y_true] -= 1
    dy /= num_examples
  
  # backpropate the gradient to the parameters (W,b)
    dW = np.dot(X.T, dy)
    db = np.sum(dy, axis=0, keepdims=True)
  
  # perform parameter update
    W += -step_size * dW
    b += -step_size * db
# Out:
# iteration 0: cost 1.195969
# iteration 1000: cost 0.771212
# iteration 2000: cost 0.771212
# iteration 3000: cost 0.771212
# iteration 4000: cost 0.771212
# iteration 5000: cost 0.771212
# iteration 6000: cost 0.771212
# iteration 7000: cost 0.771212
# iteration 8000: cost 0.771212
# iteration 9000: cost 0.771212

# %% [markdown]
# We get accuracy of NN on the training set

# %%
output = np.dot(Xtot, W) + b
predicted_class = np.argmax(output, axis=1)
print('training accuracy: %.2f' % (np.mean(predicted_class == y_true_tot)))
# Out:
# training accuracy: 0.52

# %% [markdown]
# and we plot the results of our classification

# %%
h = 0.02
x_min, x_max = Xtot[:, 0].min() - 1, Xtot[:, 0].max() + 1
y_min, y_max = Xtot[:, 1].min() - 1, Xtot[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = np.dot(np.c_[xx.ravel(), yy.ravel()], W) + b
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)
fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.viridis, alpha=0.4)
plt.scatter(Xtot[:, 0], Xtot[:, 1], c=y_true_tot[:], s=40, cmap=plt.cm.viridis)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.savefig('tutorial1_linear.pdf')

# %% [markdown]
# the linear classifier is unable to distinguish the three non linear arms

# %% [markdown]
# # Train a fully connected NN

# %% [markdown]
# we now add to the linear classifier an hidden layer, made of 100 neurons which are activated with a non linear ReLU function. In this way we are building a proper fully connected NN!
#
#
# <img src="fully_connected_NN_img.png" alt="drawing" width="300"/>

# %%
X = Xtot
y_true = y_true_tot
hL = 100 # size of hidden layer
W1 = 0.01 * np.random.randn(D, hL)
b1 = np.zeros((1,hL))
W2 = 0.01 * np.random.randn(hL, K)
b2 = np.zeros((1,K))

# some hyperparameters
step_size = 1e-0

# gradient descent loop
num_examples = X.shape[0]
for i in range(10000):
    
    # evaluate class scores
    h = np.maximum(0, np.dot(X, W1) + b1) # note, ReLU activation
    y = np.dot(h, W2) + b2
  
    # compute the class probabilities
    exp_y = np.exp(y)
    probs = exp_y / np.sum(exp_y, axis=1, keepdims=True) 

    # compute loss and cost
    loss = -np.log(probs[range(num_examples),y_true])
    cost = np.sum(loss)/num_examples
    if i % 1000 == 0:
        print("iteration %d: loss %f" % (i, cost))
  
    # derivative w.r.t. y
    dy = probs
    dy[range(num_examples),y_true] -= 1
    dy /= num_examples

    # backpropate the gradient to the parameters
    # first backprop into parameters W2 and b2
    dW2 = np.dot(h.T, dy)
    db2 = np.sum(dy, axis=0, keepdims=True)
    
    # next backprop into hidden layer
    dh = np.dot(dy, W2.T)
    
    # backprop the ReLU non-linearity
    dh[h <= 0] = 0
    
    # finally into W,b
    dW1 = np.dot(X.T, dh)
    db1 = np.sum(dh, axis=0, keepdims=True)
    
    # perform a parameter update
    W1 += -step_size * dW1
    b1 += -step_size * db1
    W2 += -step_size * dW2
    b2 += -step_size * db2
# Out:
# iteration 0: loss 1.098651
# iteration 1000: loss 0.184477
# iteration 2000: loss 0.057414
# iteration 3000: loss 0.037968
# iteration 4000: loss 0.030427
# iteration 5000: loss 0.026395
# iteration 6000: loss 0.023567
# iteration 7000: loss 0.021767
# iteration 8000: loss 0.020530
# iteration 9000: loss 0.019580

# %% [markdown]
# We get accuracy of NN on the training set

# %%
h = np.maximum(0, np.dot(Xtot, W1) + b1)
y = np.dot(h, W2) + b2
predicted_class = np.argmax(y, axis=1)
print('training accuracy: %.4f' % (np.mean(predicted_class == y_true_tot)))
# Out:
# training accuracy: 0.9933

# %% [markdown]
# and plotn results

# %%
plt.figure(figsize=(10, 12))
# plot the resulting classifier
h = 0.02
x_min, x_max = Xtot[:, 0].min() - 1, Xtot[:, 0].max() + 1
y_min, y_max = Xtot[:, 1].min() - 1, Xtot[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = np.dot(np.maximum(0, np.dot(np.c_[xx.ravel(), yy.ravel()], W1) + b1), W2) + b2
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)
fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.viridis, alpha=0.4)
plt.scatter(Xtot[:, 0], Xtot[:, 1], c=y_true_tot, s=40, cmap=plt.cm.viridis)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.savefig('tutorial1_nn.pdf')

# %% [markdown]
# # Define and train a similar NN with Keras
# In the previous cells we have built our fully connected (dense) NN, step by step, coding the forward  and the backpropagations.
# That is a meaningful excercise to do once in a life, but in practice there is no need for doing that. There exist several opensource libraries for NN. Here we use Keras with Tensorflow backend.
#
# https://keras.io

# %% [markdown]
# first we load the needed modules from the keras library

# %%
from keras.models import Sequential
from keras.layers import  Dense, Dropout
from keras import losses
from keras.utils import np_utils
from keras.optimizers import Adam

# %% [markdown]
# We define our fully connected NN as a Keras Sequential models where layers are add one after the other.

# %%
model = Sequential()
model.add(Dense(.., input_dim=.. , activation='..'))
model.add(Dense(.., activation='softmax'))
# Out:
# WARNING:tensorflow:From /Users/niki/Library/miniconda3/envs/py36n/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# the summary of the NN architecture can be easily printed

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               300
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 603
# Trainable params: 603
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# we then compile the model, defining a loss function, an optimizer for computing minimization, and a metric used to get the the NN performance

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %% [markdown]
# differently from what we have done before we divide our set of data in training (80%), validation (10%) and test (10%) sets. We train the network only on the training set.

# %%
Ntot = len(Xtot)
tot_ind = np.arange(Ntot)
train_ind = np.random.choice(tot_ind, int(Ntot*0.8))
tot_ind = np.delete(tot_ind, train_ind)
val_ind = np.random.choice(tot_ind,int(len(tot_ind)/2))
test_ind = np.delete(tot_ind, val_ind)
# Out:
# /Users/niki/Library/miniconda3/envs/py36n/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: in the future out of bounds indices will raise an error instead of being ignored by `numpy.delete`.

# %%
y_cat = np_utils.to_categorical(y_true_tot)

# %% [markdown]
# We train the model on the training set and validate while training

# %%
history = model.fit(Xtot[train_ind], y_cat[train_ind], epochs=1000, 
                    verbose=True, validation_data=(Xtot[val_ind], y_cat[val_ind]))
# Out:
# Train on 240 samples, validate on 65 samples
# Epoch 1/1000
# 240/240 [==============================] - 0s 119us/step - loss: 0.1093 - acc: 0.9792 - val_loss: 0.2029 - val_acc: 0.9385
# Epoch 2/1000
# 240/240 [==============================] - 0s 108us/step - loss: 0.1001 - acc: 0.9708 - val_loss: 0.1651 - val_acc: 0.9692
# Epoch 3/1000
# 240/240 [==============================] - 0s 107us/step - loss: 0.0896 - acc: 0.9792 - val_loss: 0.1630 - val_acc: 0.9692
# Epoch 4/1000
# 240/240 [==============================] - 0s 73us/step - loss: 0.0838 - acc: 0.9833 - val_loss: 0.1467 - val_acc: 0.9692
# Epoch 5/1000
# 240/240 [==============================] - 0s 58us/step - loss: 0.0823 - acc: 0.9833 - val_loss: 0.1159 - val_acc: 0.9692
# Epoch 6/1000
# 240/240 [==============================] - 0s 66us/step - loss: 0.0762 - acc: 0.9833 - val_loss: 0.1150 - val_acc: 0.9692
# Epoch 7/1000
# 240/240 [==============================] - 0s 56us/step - loss: 0.0728 - acc: 0.9833 - val_loss: 0.1045 - val_acc: 0.9692
# Epoch 8/1000
# 240/240 [==============================] - 0s 51us/step - loss: 0.0696 - acc: 0.9833 - val_loss: 0.0834 - val_acc: 0.9692
# Epoch 9/1000
# 240/240 [==============================] - 0s 45us/step - loss: 0.0651 - acc: 0.9833 - val_loss: 0.0798 - val_acc: 0.9692
# Epoch 10/1000
# 240/240 [==============================] - 0s 48us/step - loss: 0.0637 - acc: 0.9833 - val_loss: 0.0776 - val_acc: 0.9692
# Epoch 11/1000
# 240/240 [==============================] - 0s 51us/step - loss: 0.0601 - acc: 0.9833 - val_loss: 0.0577 - val_acc: 0.9846
# Epoch 12/1000
# 240/240 [==============================] - 0s 51us/step - loss: 0.0602 - acc: 0.9750 - val_loss: 0.0556 - val_acc: 0.9846
# Epoch 13/1000
# 240/240 [==============================] - 0s 49us/step - loss: 0.0569 - acc: 0.9833 - val_loss: 0.0594 - val_acc: 0.9692
# Epoch 14/1000
# 240/240 [==============================] - 0s 48us/step - loss: 0.0561 - acc: 0.9833 - val_loss: 0.0610 - val_acc: 0.9692
# Epoch 15/1000
# 240/240 [==============================] - 0s 51us/step - loss: 0.0553 - acc: 0.9833 - val_loss: 0.0598 - val_acc: 0.9692
# Epoch 16/1000
# 240/240 [==============================] - 0s 56us/step - loss: 0.
1000
# 240/240 [==============================] - 0s 45us/step - loss: 0.0207 - acc: 0.9917 - val_loss: 0.0997 - val_acc: 0.9846
# Epoch 977/1000
# 240/240 [==============================] - 0s 43us/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.1013 - val_acc: 0.9846
# Epoch 978/1000
# 240/240 [==============================] - 0s 44us/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.1000 - val_acc: 0.9846
# Epoch 979/1000
# 240/240 [==============================] - 0s 44us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0992 - val_acc: 0.9846
# Epoch 980/1000
# 240/240 [==============================] - 0s 42us/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.0980 - val_acc: 0.9846
# Epoch 981/1000
# 240/240 [==============================] - 0s 49us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0983 - val_acc: 0.9846
# Epoch 982/1000
# 240/240 [==============================] - 0s 46us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0988 - val_acc: 0.9846
# Epoch 983/1000
# 240/240 [==============================] - 0s 40us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0993 - val_acc: 0.9846
# Epoch 984/1000
# 240/240 [==============================] - 0s 45us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0972 - val_acc: 0.9846
# Epoch 985/1000
# 240/240 [==============================] - 0s 44us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0967 - val_acc: 0.9846
# Epoch 986/1000
# 240/240 [==============================] - 0s 49us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0978 - val_acc: 0.9846
# Epoch 987/1000
# 240/240 [==============================] - 0s 42us/step - loss: 0.0201 - acc: 0.9917 - val_loss: 0.0987 - val_acc: 0.9846
# Epoch 988/1000
# 240/240 [==============================] - 0s 44us/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.0998 - val_acc: 0.9846
# Epoch 989/1000
# 240/240 [==============================] - 0s 46us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.1003 - val_acc: 0.9846
# Epoch 990/1000
# 240/240 [==============================] - 0s 50us/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.1006 - val_acc: 0.9846
# Epoch 991/1000
# 240/240 [==============================] - 0s 45us/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.1002 - val_acc: 0.9846
# Epoch 992/1000
# 240/240 [==============================] - 0s 48us/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.1002 - val_acc: 0.9846
# Epoch 993/1000
# 240/240 [==============================] - 0s 40us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.1013 - val_acc: 0.9846
# Epoch 994/1000
# 240/240 [==============================] - 0s 39us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.1008 - val_acc: 0.9846
# Epoch 995/1000
# 240/240 [==============================] - 0s 47us/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.1022 - val_acc: 0.9846
# Epoch 996/1000
# 240/240 [==============================] - 0s 41us/step - loss: 0.0204 - acc: 0.9917 - val_loss: 0.1012 - val_acc: 0.9846
# Epoch 997/1000
# 240/240 [==============================] - 0s 39us/step - loss: 0.0200 - acc: 0.9917 - val_loss: 0.0992 - val_acc: 0.9846
# Epoch 998/1000
# 240/240 [==============================] - 0s 44us/step - loss: 0.0201 - acc: 0.9917 - val_loss: 0.0986 - val_acc: 0.9846
# Epoch 999/1000
# 240/240 [==============================] - 0s 42us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0970 - val_acc: 0.9846
# Epoch 1000/1000
# 240/240 [==============================] - 0s 44us/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.0976 - val_acc: 0.9846

# %% [markdown]
# The performance of the NN during training are saved in a python dictoray

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# We can evaluate the trained model

# %%
print(model.evaluate(Xtot[train_ind], y_cat[train_ind]))
print('')
print(model.evaluate(Xtot[test_ind], y_cat[test_ind]))
# Out:
# 240/240 [==============================] - 0s 21us/step
# [0.021171340346336366, 0.9958333333333333]
#
# 108/108 [==============================] - 0s 32us/step
# [0.18086108130713305, 0.9537037037037037]

# %% [markdown]
# predict classes

# %%
y_test = model.predict(Xtot[test_ind])
# Out:
# (108, 3)

# %% [markdown]
# and plot results

# %%
sub_set = train_ind
plt.figure(figsize=(10, 12))
# plot the resulting classifier
h = 0.02
x_min, x_max = Xtot[sub_set, 0].min() - 1, Xtot[sub_set, 0].max() + 1
y_min, y_max = Xtot[sub_set, 1].min() - 1, Xtot[sub_set, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = np.argmax(Z, axis=1)
Z = Z.reshape(xx.shape)
fig = plt.figure()
plt.contourf(xx, yy, Z, cmap=plt.cm.viridis, alpha=0.4)
plt.scatter(Xtot[sub_set, 0], Xtot[sub_set, 1], c=y_true_tot[sub_set], s=40, cmap=plt.cm.viridis)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
# Out:
# (-1.8995873357032895, 1.8204126642967138)
